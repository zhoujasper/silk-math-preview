# %% [markdown]
# # Jupyter 跨单元格宏
#
# 下面三行只有定义。默认不预览、也不报“渲染为空”。打开「定义也预览」才会画出展开结果。
#
# $\def\A{\mathbf{A}}$
# $\newcommand{\R}{\mathbb{R}}$
# $\newcommand{\nbNorm}[1]{\left\lVert #1 \right\rVert}$
#
# 本格使用（应能展开）：$u\in\R$，$\nbNorm{\A x}$。

# %%
# 代码格不参与宏收集。下面这行不能让后面的 markdown 认识 \\fromCode
# $\\newcommand{\\fromCode}{\\mathbf{Z}}$
import numpy as np
N = 4

# %% [markdown]
# ## 后面格子应能用前面的 `\A` / `\R`
#
# 把光标放进行尾公式，预览应从公式下方往右：前面垫一些文字 $\nbNorm{\A u}$。
#
# 行内 $\A u = 0$，$x\in\R^n$。
#
# 独立段：
#
# $$
# \underbrace{\A u}_{=0 \text{ by the PDE}} \quad \text{on } \R^d
# $$
#
# 代码格里的 `\fromCode` 不应存在：$\fromCode$ 应为红字。

# %% [markdown]
# ## 分隔符、矩阵、划掉
#
# 圆括号 \(\frac{1}{2}\pi\)。方括号：
#
# \[
# \begin{pmatrix} 1 & 0 \\ 0 & 1 \end{pmatrix}
# \quad
# \begin{bmatrix} a & b \\ c & d \end{bmatrix}
# \quad
# \cancel{h^2}+\sqrt{1+x^2}
# \]
#
# 美元套 equation：
#
# $$
# \begin{equation}
#   \A^\top \A v = \lambda v
# \end{equation}
# $$
#
# \[
# \begin{align}
#   x &= y+z \\
#   u &= v+w
# \end{align}
# \]

# %% [markdown]
# ## GFM 表（单元格里的数学，含竖线）
#
# | 项 | 记号 | 值 |
# | --- | :---: | ---: |
# | 矩阵 | $\A$ | $n\times n$ |
# | 能量 | $E(u)$ | $\int |\nabla u|^2$ |
# | 绝对值 | $|x|$ | $\lVert v \rVert$ |
#
# 行内代码 `$not math$` 把光标放进反引号里也应预览。

# %% [markdown]
# ## 长公式（预览应在公式下方，不要翻到上面）
#
# $$
# \begin{aligned}
#   a_1 &= 1 \\
#   a_2 &= 2 \\
#   a_3 &= 3 \\
#   a_4 &= 4 \\
#   a_5 &= 5 \\
#   a_6 &= 6 \\
#   a_7 &= 7 \\
#   a_8 &= 8
# \end{aligned}
# $$
